# %% [markdown]
# # Cuiman GUI Usage (App)
#
# The Cuiman API client also provides a user-friendly GUI which can b:
#
# - `client.show()`: execute a given process execution request,
# - `client.show_jobs()`: show all jobs resulting from process execution,
# - `client.show_job()`: show the details of a specific job.
#
# Apart from that, they share the same interface. In the following, we visit all the features by example.
#
# The client expects a running server that conforms to the [OGC API - Process: Part 1, Version 1.0]().
# If you don't have one available, you can also run the project's server
# with a test configuration:
#
# ```bash
# wraptile run -- wraptile.services.local.testing:service
# ```

# %%
from cuiman import Client

# %%
client = Client(api_url="http://localhost:8008/", auth_type="none")

# %%
app = client.show_app(height=600)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 app = client.show_app(height=600)
#
# File ~\Projects\eozilla\cuiman\src\cuiman\api\client_app_mixin.py:96, in ClientAppMixin.show_app(self, compact, debug, scheme, width, height, display)
#      93 remote_store = App.create_remote_store()
#      95 # noinspection PyTypeChecker
# ---> 96 serve_result = serve(
#      97     self.config,
#      98     remote_store,
#      99     compact=compact_,
#     100     debug=debug,
#     101     scheme=scheme,
#     102     width=width,
#     103     height=height,
#     104     display=display_,
#     105 )
#     107 return App(remote_store, serve_result)
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\serve.py:29, in serve(config, store, compact, debug, scheme, width, height, display)
#      16 def serve(
#      17     config: ClientConfig,
#      18     store: rs.Store,
#    (...)     25     display: Literal["browser", "notebook", "none"] = "notebook",
#      26 ) -> rs.ServeResult:
#      27     app_dist = _get_app_dist_url_or_dir(os.environ.get(DIST_ENV_VAR))
# ---> 29     server = rs.serve(
#      30         rs.Service(store),
#      31         ui_dist=app_dist,
#      32         host="127.0.0.1",
#      33         display="none",
#      34     )
#      36     if display == "none":
#      37         return server
#
# File ~\Projects\eozilla\.pixi\envs\default\Lib\site-packages\remotestate\serve.py:152, in serve(service, ui_dist, mounts, app, display, width, height, host, port, **uvicorn_settings)
#     150 server_url = f"http://{host}:{port}"
#     151 ws_url = f"ws://{host}:{port}/ws"
# --> 152 mounts_, ui_base_url = _resolve_ui_dist(
#     153     ui_dist,
#     154     mounts=mounts,
#     155     server_url=server_url,
#     156 )
#     158 rs_server = Server(service=service, mounts=mounts_, app=app)
#     160 uvicorn_settings.update(host=host, port=port)
#
# File ~\Projects\eozilla\.pixi\envs\default\Lib\site-packages\remotestate\serve.py:217, in _resolve_ui_dist(ui_dist, mounts, server_url)
#     215     ui_base_url = ui_dist
#     216 elif ui_dist is not None:
# --> 217     mounts_["/"] = StaticFiles(directory=ui_dist, html=True)
#     218 return mounts_, ui_base_url
#
# File ~\Projects\eozilla\.pixi\envs\default\Lib\site-packages\starlette\staticfiles.py:56, in StaticFiles.__init__(self, directory, packages, html, check_dir, follow_symlink)
#      54 self.follow_symlink = follow_symlink
#      55 if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56     raise RuntimeError(f"Directory '{directory}' does not exist")
#
# RuntimeError: Directory 'C:\Users\norma\Projects\eozilla-app\dist' does not exist

# %%
app.process_pequests.sleep_a_while.inputs.duration
# Out:
# 10

# %%
app.process_requests.sleep_a_while.inputs.duration = 150

# %%
app.serve_result
# Out:
# ServeResult(host='127.0.0.1', port=50883, server_url='http://127.0.0.1:50883', ws_url='ws://127.0.0.1:50883/ws', ui_base_url='http://127.0.0.1:50883', ui_url='http://127.0.0.1:50883?t=1783515581&ws=ws%3A%2F%2F127.0.0.1%3A50883%2Fws', app=<fastapi.applications.FastAPI object at 0x00000244B4B01550>, server=<uvicorn.server.Server object at 0x00000244B4C78B90>, thread=<Thread(Thread-5 (run), started daemon 27428)>)
