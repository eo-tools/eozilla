# %% [markdown]
# # Cuiman App Usage
#
# The client expects a running server that conforms to the [OGC API - Process: Part 1, Version 1.0]().
# If you don't have one available, you can also run the project's server
# with a test configuration:
#
# ```bash
# wraptile run -- wraptile.services.local.testing:service
# ```

# %%
from cuiman import Client
from gavicore.models import ProcessRequest

# %%
client = Client()
# client

# %%
client.show_app()
# Out:
# INFO:     Started server process [40568]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://localhost:9753 (Press CTRL+C to quit)
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:9753?t=1781154591&ws=ws%3A%2F%2Flocalhost%3A9753%2Fws"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# INFO:     ::1:55630 - "GET /?t=1781154591&ws=ws%3A%2F%2Flocalhost%3A9753%2Fws HTTP/1.1" 200 OK
# INFO:     ::1:55630 - "GET /assets/index-Bjf1AEn2.js HTTP/1.1" 304 Not Modified
# INFO:     ::1:60984 - "GET /assets/index-DXGCQZEF.css HTTP/1.1" 304 Not Modified
# INFO:     ::1:60984 - "GET /privacy.md HTTP/1.1" 304 Not Modified
