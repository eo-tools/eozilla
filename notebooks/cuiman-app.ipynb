# %% [markdown]
# # Cuiman App Usage
#
# The client expects a running server that conforms to the [OGC API - Process: Part 1, Version 1.0]().
# If you don't have one available, you can also run the project's server
# with a test configuration:
#
# ```bash
# wraptile run -- wraptile.services.local.testing:service
# ```

# %%
from cuiman import Client
from gavicore.models import ProcessRequest

# %%
client = Client()
# client

# %%
client.show_app()
# Out:
# INFO:     Started server process [21196]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:64365 (Press CTRL+C to quit)
# http://127.0.0.1:64365/index.html?_t=1781259601&ws=ws%3A%2F%2F127.0.0.1%3A64365%2Fws&compact=1&config=
#             <div class="eozilla-frame-root"></div>
#             <script>
#             (() => {
#               function detectJupyterScheme() {
#                 const body = document.body;
#                 const root = document.documentElement;
#
#                 const themeLight =
#                   body.getAttribute("data-jp-theme-light") ??
#                   root.getAttribute("data-jp-theme-light");
#
#                 if (themeLight === "true") return "light";
#                 if (themeLight === "false") return "dark";
#
#                 const bg =
#                   getComputedStyle(root).getPropertyValue("--jp-layout-color0") ||
#                   getComputedStyle(body).backgroundColor;
#
#                 const match = bg.match(/\d+/g);
#                 if (match && match.length >= 3) {
#                   const [r, g, b] = match.slice(0, 3).map(Number);
#                   const luminance = (0.2126 * r + 0.7152 * g + 0.0722 * b) / 255;
#                   return luminance < 0.5 ? "dark" : "light";
#                 }
#
#                 return null;
#               }
#
#               const root = document.currentScript.previousElementSibling;
#               const scheme = detectJupyterScheme();
#               const src = new URL("http://127.0.0.1:64365/index.html?_t=1781259601&ws=ws%3A%2F%2F127.0.0.1%3A64365%2Fws&compact=1&config=", window.location.href);
#
#               if (scheme) {
#                 src.searchParams.set("scheme", scheme);
#               }
#
#               const iframe = document.createElement("iframe");
#               iframe.src = src.toString();
#               iframe.width = "100%";
#               iframe.height = "600";
#               iframe.style.border = "0";
#               iframe.style.width = "100%";
#               iframe.style.height = "600px";
#               iframe.allow = "clipboard-read; clipboard-write";
#
#               root.replaceChildren(iframe);
#             })();
#             </script>
# INFO:     127.0.0.1:49447 - "GET /index.html?_t=1781259601&ws=ws%3A%2F%2F127.0.0.1%3A64365%2Fws&compact=1&config=&scheme=dark HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49447 - "GET /assets/index-BPwVMMwO.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56855 - "GET /assets/index-D1QHV3gI.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:49447 - "GET /privacy.md HTTP/1.1" 200 OK

# %%
client.app_store.primes_between.inputs.duration = 40
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 client.app_store.primes_between.inputs.duration = 40
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:46, in ProcessStore.inputs(self)
#      44 @property
#      45 def inputs(self) -> ProcessIO[Any]:
# ---> 46     return ProcessIO(self.store, self.process_id, "processesInputs")
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:23, in ProcessIO.__init__(self, store, process_id, io_key)
#      17 def __init__(
#      18     self,
#      19     store: remotestate.Store,
#      20     process_id: str,
#      21     io_key: Literal["processesInputs", "processesOutputs"],
#      22 ):
# ---> 23     self.store = store
#      24     self.path = f"{io_key}.{process_id}"
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:30, in ProcessIO.__setattr__(self, key, value)
#      29 def __setattr__(self, key: str, value: T):
# ---> 30     self.store.set(f"{self.path}.{key}", value)
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:27, in ProcessIO.__getattr__(self, key)
#      26 def __getattr__(self, key: str) -> T | None:
# ---> 27     return self.store.get(f"{self.path}.{key}")
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:27, in ProcessIO.__getattr__(self, key)
#      26 def __getattr__(self, key: str) -> T | None:
# ---> 27     return self.store.get(f"{self.path}.{key}")
#
#     [... skipping similar frames: ProcessIO.__getattr__ at line 27 (722 times)]
#
# File ~\Projects\eozilla\cuiman\src\cuiman\app\store.py:27, in ProcessIO.__getattr__(self, key)
#      26 def __getattr__(self, key: str) -> T | None:
# ---> 27     return self.store.get(f"{self.path}.{key}")
#
# RecursionError: Stack overflow (used 1953 kB)
